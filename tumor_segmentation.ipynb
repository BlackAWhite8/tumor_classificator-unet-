# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision.transforms.functional import crop
from PIL import Image
import json
import os
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import cv2
import numpy as np
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
import random

# %%
class Block(nn.Module):
  def __init__(self, in_c, out_c, kernel, stride=1, pad=0):
    super().__init__()

    self.act = nn.GELU()
    self.conv = nn.Conv2d(in_c, out_c, kernel, stride, pad)
    self.norm = nn.BatchNorm2d(out_c)

  def forward(self, x):
    out = self.conv(x)
    out = self.norm(out)
    out = self.act(out)
    return out

# %%
class UnetBlock(nn.Module):
  def __init__(self, n_c, out_c, low_block=None):
    super().__init__()

    self.cv1 = Block(n_c, out_c, 3, stride=2, pad=2)
    self.cv2 = Block(n_c*2, int(out_c/2), 1, stride=1, pad=0)
    self.cv3 = Block(n_c, int(out_c/2), 5, stride=1, pad=3)

  def forward(self, x, unpooled_x):

    out = self.cv1(x)
    out = self.cv2(out)
    out = self.cv3(out)

    _,_,h,w = out.shape
    out = F.interpolate(out, size=(h*2,w*2), mode='bilinear')
    croped_x = crop(unpooled_x, 0 ,0, h*2, w*2)

    all_features = torch.cat((out, croped_x), axis=1)

    return all_features

# %%
class UnetCut(nn.Module):
  def __init__(self):
    super().__init__()
    # image nxn input
    self.act = nn.GELU()
    #top level
    self.cv1 = Block(1, 128, 3, stride=1, pad=0)
    self.cv2 = Block(128, 64, 1, stride=1, pad=0)
    self.cv3 = Block(64, 64, 5, stride=1, pad=1)

    #low level
    self.pl = nn.MaxPool2d(2)
    self.inner_block = UnetBlock(64,128)

    # top level(after long skip connection)
    self.cv7 = Block(128, 64, 3, stride=1, pad=0)
    self.cv8 = Block(64, 64, 3, stride=1, pad=0)
    self.cv9 = Block(64, 1, 1, stride=1, pad=0)

  def forward(self, x):
    up_x = self.cv1(x)
    up_x = self.cv2(up_x)
    up_x = self.cv3(up_x)


    low_x = self.pl(up_x)

    all_features = self.inner_block(low_x, up_x)
    all_features = self.act(all_features)

    del up_x
    del low_x
    print(all_features.shape)
    all_features = self.cv7(all_features)
    print(all_features.shape)
    all_features = self.cv8(all_features)
    print(all_features.shape)
    all_features = self.cv9(all_features)
    print(all_features.shape)
    return all_features

# %%
ten = torch.rand(1,1,512,512)
ten.shape
# Out:
# torch.Size([1, 1, 512, 512])

# %%
t = crop(ten, 0,0,260,260)
t.shape
# Out:
# torch.Size([1, 1, 260, 260])

# %%
u = UnetCut()

# %%
res = u.forward(ten)
# Out:
# torch.Size([1, 128, 260, 260])
# torch.Size([1, 64, 258, 258])
# torch.Size([1, 64, 256, 256])
# torch.Size([1, 1, 256, 256])

# %%
res = u.forward(ten)
# Out:
# torch.Size([1, 128, 18, 18])
# torch.Size([1, 64, 16, 16])
# torch.Size([1, 64, 14, 14])
# torch.Size([1, 1, 14, 14])

# %%
with open('/content/drive/MyDrive/tumor_json/_annotations.coco.json') as file:
  data = json.load(file)

# %%
print(data['images'][0])
# Out:
# {'id': 0, 'license': 1, 'file_name': '2256_jpg.rf.3afd7903eaf3f3c5aa8da4bbb928bc19.jpg', 'height': 640, 'width': 640, 'date_captured': '2023-08-19T04:37:54+00:00'}

# %%
dir_path = "/content/drive/MyDrive/train"
valid_path = "/content/drive/MyDrive/valid"

# %%
 img_data = data['images'][0]

# %%
def imagePath(dir_path, img_data):
  file_name = img_data['file_name']
  path = os.path.join(dir_path, file_name)
  return path

# %%
def get_annotations(img_data, annotations):

  img_annotations = [ann for ann in annotations if ann['image_id'] == img_data['id']]
  return img_annotations

# %%
annot = get_annotations(img_data, data['annotations'])
annot
# Out:
# [{'id': 0,
#   'image_id': 0,
#   'category_id': 1,
#   'bbox': [145, 239, 168.75, 162.5],
#   'area': 27421.875,
#   'segmentation': [[313.75,
#     238.75,
#     145,
#     238.75,
#     145,
#     401.25,
#     313.75,
#     401.25,
#     313.75,
#     238.75]],
#   'iscrowd': 0}]

# %%
for i, img in enumerate(data['images']):
  print(i, img)
  break
# Out:
# 0 {'id': 0, 'license': 1, 'file_name': '2256_jpg.rf.3afd7903eaf3f3c5aa8da4bbb928bc19.jpg', 'height': 640, 'width': 640, 'date_captured': '2023-08-19T04:37:54+00:00'}

# %%
def show_areas(dir, data,n):
  annotations = data['annotations']
  fig , ax = plt.subplots(n,1, figsize=(20,20))
  i = 0
  for img in data['images'][:n]:
    path = imagePath(dir, img)
    try:
      path_checking = Image.open(path)
    except FileNotFoundError:
      print('file is not found, skipping...')
      continue
    draw_img = cv2.imread(path)
    img_annotations = get_annotations(img, annotations)
    points = img_annotations[0]['segmentation']
    points = np.array(points, np.int64)
    points = points.reshape((-1,2))
    cv2.polylines(draw_img, [points], True, (255,0,0), 3)
    ax[i].imshow(draw_img)
    ax[i].axis('off')
    i += 1
  plt.show()

# %%
show_areas(dir_path, data, 10)

# %%
def create_masks(data, dir, output_dir):
  annotations = data['annotations']
  if not os.path.exists(output_dir):
    os.mkdir(output_dir)
  for img in data['images']:
    mask_path = os.path.join(output_dir, img['file_name'])
    path = imagePath(dir, img)
    try:
      path_checking = Image.open(path)
    except FileNotFoundError:
      print('file is not found, skipping...')
      continue
    mask = np.zeros((img['height'], img['width']), dtype=np.uint8)
    img_annotations = get_annotations(img, annotations)
    for ann in img_annotations:
      for seg in ann['segmentation']:
        poly = np.int64(np.array(seg).reshape(-1,2))
        cv2.fillPoly(mask, [poly.astype(np.int32)], color=1)
    Image.fromarray(mask*255).save(mask_path)

# %%
with open('/content/drive/MyDrive/tumor_json/valid_annot.json') as file:
  valid_data = json.load(file)

# %%
create_masks(data, dir_path, '/content/sample_data/test_masks')

# %%
create_masks(valid_data, valid_path, '/content/sample_data/valid_masks')

# %%
class ProblemDataset(Dataset):
  def __init__(self, root_dir, img_dir, masks_dir, transform=None):
    self.root_dir = root_dir
    self.masks_dir = masks_dir
    self.img_dir = img_dir
    self.masks = os.listdir(self.masks_dir)
    self.images = os.listdir(self.img_dir)
    self.transform = transform

  def __len__(self):
    return len(self.masks)

  def __getitem__(self, idx):
    img_name = self.images[idx]
    mask_name = self.masks[idx]
    img_path = os.path.join(self.img_dir, img_name)
    mask_path = os.path.join(self.masks_dir, mask_name)


    img = Image.open(img_path).convert('RGB')
    gray_img = img.convert('L')
    mask = Image.open(mask_path).convert('L')

    if self.transform:
      gray_img = self.transform(gray_img)
      mask = self.transform(mask)

    return gray_img, mask

# %%
dataset = ProblemDataset('/content/sample_data', '/content/drive/MyDrive/train', '/content/sample_data/tumor_masks', transform=transforms.ToTensor())
valid_dataset = ProblemDataset('/content/sample_data', '/content/drive/MyDrive/valid', '/content/sample_data/valid_masks', transform=transforms.ToTensor())

# %%
train_loader = DataLoader(dataset, shuffle=True)
valid_loader = DataLoader(valid_dataset, shuffle=True)

# %%
train_images = []
train_masks = []
for _, (image, mask) in enumerate(train_loader):
  train_images.append(image)
  train_masks.append(mask)

train_images = torch.stack(train_images)
train_masks = torch.stack(train_masks)

# %%
valid_images = []
valid_masks = []
for _, (image, mask) in enumerate(valid_loader):
  valid_images.append(image)
  valid_masks.append(mask)

valid_images = torch.stack(valid_images)
valid_masks = torch.stack(valid_masks)

# %%
print(train_images.shape, train_masks.shape)
# Out:
# torch.Size([1359, 1, 640, 640]) torch.Size([1359, 1, 640, 640])

# %%
train_images = train_images.reshape(train_images.shape[0],train_images.shape[2],train_images.shape[3],train_images.shape[4])
train_masks = train_masks.reshape(train_masks.shape[0],train_masks.shape[2],train_masks.shape[3],train_masks.shape[4])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-45-25a126883b0e> in <cell line: 1>()
# ----> 1 train_images = train_images.reshape(train_images.shape[0],train_images.shape[2],train_images.shape[3],train_images.shape[4])
#       2 train_masks = train_masks.reshape(train_masks.shape[0],train_masks.shape[2],train_masks.shape[3],train_masks.shape[4])
#
# IndexError: tuple index out of range

# %%
valid_images = valid_images.reshape(valid_images.shape[0],valid_images.shape[2],valid_images.shape[3],valid_images.shape[4])
valid_masks = valid_masks.reshape(valid_masks.shape[0],valid_masks.shape[2],valid_masks.shape[3],valid_masks.shape[4])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-47-99a97b1431aa> in <cell line: 1>()
# ----> 1 valid_images = valid_images.reshape(valid_images.shape[0],valid_images.shape[2],valid_images.shape[3],valid_images.shape[4])
#       2 valid_masks = valid_masks.reshape(valid_masks.shape[0],valid_masks.shape[2],valid_masks.shape[3],valid_masks.shape[4])
#
# IndexError: tuple index out of range

# %%
print(train_images.shape, train_masks.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-ab3a0d5c60e6> in <cell line: 1>()
# ----> 1 print(train_images.shape, train_masks.shape)
#
# NameError: name 'train_images' is not defined

# %%
print(valid_images.shape, valid_masks.shape)
# Out:
# torch.Size([429, 1, 640, 640]) torch.Size([429, 1, 640, 640])

# %%
np.random.seed(0)
torch.manual_seed(0)
torch.backends.cudnn.deterministic = True
random.seed(0)

# %%
#device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device = 'cpu'

# %%
train_images = train_images.to(device)
train_masks = train_masks.to(device)
valid_images = valid_images.to(device)
valid_masks = valid_masks.to(device)

# %%
u = UnetCut().to(device)

# %%
optimizer = torch.optim.Adam(u.parameters(), 1e-3)
loss = nn.BCELoss()

# %%
batch_size = 64

acc_hist = []

for epoch in range(100):
    inds = np.random.permutation(len(train_images))
    for st in range(0, len(train_images), batch_size):
      optimizer.zero_grad()
      u.train()

      batch_imgs = train_images[inds[st:st+batch_size]].to(device)
      batch_masks = train_masks[inds[st:st+batch_size]].to(device)

      preds = u.forward(batch_imgs)

      loss_val = loss(preds, batch_masks)
      loss_val.backward()

      optimizer.step()

      if epoch % 10 == 0:
        u.eval()
        valid_preds = u.forward(valid_images)
        print(loss(valid_preds, valid_masks))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-61cde9c3d99b> in <cell line: 5>()
#       4
#       5 for epoch in range(100):
# ----> 6     inds = np.random.permutation(len(train_images))
#       7     for st in range(0, len(train_images), batch_size):
#       8       optimizer.zero_grad()
#
# NameError: name 'np' is not defined
